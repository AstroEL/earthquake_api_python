# %%
# import the libraries
import requests
import pandas as pd

# %%
#store the link
url = 'https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2022-07-01&endtime=2022-07-31'

#check to see if we get a response from the API
r = requests.get(url)
r
# Out:
# <Response [200]>

# %%
from pandas import json_normalize
import json

data = r.json()
d0 = json_normalize(data,'features')
d0.head()
df = pd.DataFrame(d0)
df.head()
# Out:
#       type            id  properties.mag                    properties.place  \
# 0  Feature  ak0229pcf7rl            2.60         113 km E of Chignik, Alaska
# 1  Feature    nc73764496            1.18  11km ENE of Hidden Valley Lake, CA
# 2  Feature    av91650536            0.22            41 km NE of Adak, Alaska
# 3  Feature    ci40072567            1.30       11km ESE of Lake Isabella, CA
# 4  Feature    ci40072551            1.35             7km WSW of Beaumont, CA
#
#    properties.time  properties.updated properties.tz  \
# 0    1659225367215       1659225585732          None
# 1    1659224909800       1659249070805          None
# 2    1659224154190       1659471266410          None
# 3    1659224149970       1659369063102          None
# 4    1659223381510       1659368607850          None
#
#                                       properties.url  \
# 0  https://earthquake.usgs.gov/earthquakes/eventp...
# 1  https://earthquake.usgs.gov/earthquakes/eventp...
# 2  https://earthquake.usgs.gov/earthquakes/eventp...
# 3  https://earthquake.usgs.gov/earthquakes/eventp...
# 4  https://earthquake.usgs.gov/earthquakes/eventp...
#
#                                    properties.detail  properties.felt  ...  \
# 0  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN  ...
# 1  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN  ...
# 2  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN  ...
# 3  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN  ...
# 4  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN  ...
#
#                                     properties.types  properties.nst  \
# 0                                ,origin,phase-data,             NaN
# 1     ,nearby-cities,origin,phase-data,scitech-link,            19.0
# 2                                ,origin,phase-data,             4.0
# 3     ,nearby-cities,origin,phase-data,scitech-link,            32.0
# 4  ,focal-mechanism,nearby-cities,origin,phase-da...            69.0
#
#   properties.dmin properties.rms  properties.gap  properties.magType  \
# 0             NaN           0.66             NaN                  ml
# 1         0.03003           0.07            88.0                  md
# 2             NaN           0.27           311.0                  ml
# 3         0.10920           0.16            60.0                  ml
# 4         0.13720           0.16            27.0                  ml
#
#   properties.type                            properties.title geometry.type  \
# 0      earthquake         M 2.6 - 113 km E of Chignik, Alaska         Point
# 1      earthquake  M 1.2 - 11km ENE of Hidden Valley Lake, CA         Point
# 2      earthquake            M 0.2 - 41 km NE of Adak, Alaska         Point
# 3      earthquake       M 1.3 - 11km ESE of Lake Isabella, CA         Point
# 4      earthquake             M 1.4 - 7km WSW of Beaumont, CA         Point
#
#                            geometry.coordinates
# 0                    [-156.5634, 56.2988, 31.3]
# 1              [-122.4426667, 38.8486667, 7.22]
# 2  [-176.178833333333, 52.1136666666667, 10.03]
# 3                 [-118.3585, 35.5858333, 1.98]
# 4             [-117.0481667, 33.9033333, 14.75]
#
# [5 rows x 30 columns]

# %%
df[['Longitude','Latitude','Depth']] = pd.DataFrame(df['geometry.coordinates'].tolist(),index= df.index)

# %%
df.shape
# Out:
# (9001, 33)

# %%
df.to_csv('fix column titles')

# %%
column_names = ['Type','ID','mag','place','time','updated','tz','url','detail','felt','cdi','mmi','alert','status','tsunami','sig','net','code','ids','sources','types','nst','dmin','rms','gap','magType','type','title','geometry.type','geometry.coordinates','Longitude','Latitude','Depth'
]

# %%
df.set_axis(column_names, axis=1,inplace=True)

# %%
# #store the link
# url = 'https://earthquake.usgs.gov/fdsnws/event/1/application.json'

# #check to see if we get a response from the API
# r = requests.get(url)
# r
# months = ["01","02","03","04","05","06","07","08","09","10","11","12"]
# data = []
# for y in range(1960,2023):
#     for m in months:
#         x =requests.get(f'https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime={str(y)}-{m}-01&endtime={str(y)}-{m}-31')
#         data.append(x)

# %%
import pickle

pickle_out = open('working_eq_df','wb')
pickle.dump(df,pickle_out)
pickle_out.close()

# %%
df.tail()
# Out:
#          Type          ID   mag                       place           time  \
# 8996  Feature  ci40294568  1.10     22km ESE of Bodfish, CA  1656635685810
# 8997  Feature  nc73753036  0.83    15km NW of Parkfield, CA  1656635031610
# 8998  Feature  ci40294560  1.51     21km ESE of Bodfish, CA  1656634683580
# 8999  Feature  nc73753031  0.35   7km NW of The Geysers, CA  1656634192490
# 9000  Feature  hv73061232  2.61  9 km ENE of P?hala, Hawaii  1656633769670
#
#             updated    tz                                                url  \
# 8996  1657044736693  None  https://earthquake.usgs.gov/earthquakes/eventp...
# 8997  1656647370461  None  https://earthquake.usgs.gov/earthquakes/eventp...
# 8998  1656636372455  None  https://earthquake.usgs.gov/earthquakes/eventp...
# 8999  1656638891041  None  https://earthquake.usgs.gov/earthquakes/eventp...
# 9000  1656645988040  None  https://earthquake.usgs.gov/earthquakes/eventp...
#
#                                                  detail  felt  ...    gap  \
# 8996  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  ...   80.0
# 8997  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  ...   82.0
# 8998  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  ...   79.0
# 8999  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  ...   67.0
# 9000  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  ...  141.0
#
#       magType        type                               title  geometry.type  \
# 8996       ml  earthquake     M 1.1 - 22km ESE of Bodfish, CA          Point
# 8997       md  earthquake    M 0.8 - 15km NW of Parkfield, CA          Point
# 8998       ml  earthquake     M 1.5 - 21km ESE of Bodfish, CA          Point
# 8999       md  earthquake   M 0.4 - 7km NW of The Geysers, CA          Point
# 9000       ml  earthquake  M 2.6 - 9 km ENE of P?hala, Hawaii          Point
#
#                      geometry.coordinates   Longitude   Latitude  Depth  \
# 8996     [-118.2798333, 35.4896667, 8.65] -118.279833  35.489667   8.65
# 8997    [-120.5438333, 35.9963333, 11.14] -120.543833  35.996333  11.14
# 8998     [-118.2948333, 35.4918333, 4.88] -118.294833  35.491833   4.88
# 8999       [-122.805336, 38.822834, 2.42] -122.805336  38.822834   2.42
# 9000  [-155.394833333333, 19.2345, 33.18] -155.394833  19.234500  33.18
#
#                               Time
# 8996 1970-01-01 00:27:36.635685810
# 8997 1970-01-01 00:27:36.635031610
# 8998 1970-01-01 00:27:36.634683580
# 8999 1970-01-01 00:27:36.634192490
# 9000 1970-01-01 00:27:36.633769670
#
# [5 rows x 34 columns]

# %%
df['Time'] = pd.to_datetime(df['time'],
                      unit = 'ms')

# %%
df.tail()
# Out:
#          Type          ID   mag                       place           time  \
# 8996  Feature  ci40294568  1.10     22km ESE of Bodfish, CA  1656635685810
# 8997  Feature  nc73753036  0.83    15km NW of Parkfield, CA  1656635031610
# 8998  Feature  ci40294560  1.51     21km ESE of Bodfish, CA  1656634683580
# 8999  Feature  nc73753031  0.35   7km NW of The Geysers, CA  1656634192490
# 9000  Feature  hv73061232  2.61  9 km ENE of P?hala, Hawaii  1656633769670
#
#             updated    tz                                                url  \
# 8996  1657044736693  None  https://earthquake.usgs.gov/earthquakes/eventp...
# 8997  1656647370461  None  https://earthquake.usgs.gov/earthquakes/eventp...
# 8998  1656636372455  None  https://earthquake.usgs.gov/earthquakes/eventp...
# 8999  1656638891041  None  https://earthquake.usgs.gov/earthquakes/eventp...
# 9000  1656645988040  None  https://earthquake.usgs.gov/earthquakes/eventp...
#
#                                                  detail  felt  ...    gap  \
# 8996  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  ...   80.0
# 8997  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  ...   82.0
# 8998  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  ...   79.0
# 8999  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  ...   67.0
# 9000  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  ...  141.0
#
#       magType        type                               title  geometry.type  \
# 8996       ml  earthquake     M 1.1 - 22km ESE of Bodfish, CA          Point
# 8997       md  earthquake    M 0.8 - 15km NW of Parkfield, CA          Point
# 8998       ml  earthquake     M 1.5 - 21km ESE of Bodfish, CA          Point
# 8999       md  earthquake   M 0.4 - 7km NW of The Geysers, CA          Point
# 9000       ml  earthquake  M 2.6 - 9 km ENE of P?hala, Hawaii          Point
#
#                      geometry.coordinates   Longitude   Latitude  Depth  \
# 8996     [-118.2798333, 35.4896667, 8.65] -118.279833  35.489667   8.65
# 8997    [-120.5438333, 35.9963333, 11.14] -120.543833  35.996333  11.14
# 8998     [-118.2948333, 35.4918333, 4.88] -118.294833  35.491833   4.88
# 8999       [-122.805336, 38.822834, 2.42] -122.805336  38.822834   2.42
# 9000  [-155.394833333333, 19.2345, 33.18] -155.394833  19.234500  33.18
#
#                         Time
# 8996 2022-07-01 00:34:45.810
# 8997 2022-07-01 00:23:51.610
# 8998 2022-07-01 00:18:03.580
# 8999 2022-07-01 00:09:52.490
# 9000 2022-07-01 00:02:49.670
#
# [5 rows x 34 columns]

# %%
df.head()
# Out:
#       Type            ID   mag                               place  \
# 0  Feature  ak0229pcf7rl  2.60         113 km E of Chignik, Alaska
# 1  Feature    nc73764496  1.18  11km ENE of Hidden Valley Lake, CA
# 2  Feature    av91650536  0.22            41 km NE of Adak, Alaska
# 3  Feature    ci40072567  1.30       11km ESE of Lake Isabella, CA
# 4  Feature    ci40072551  1.35             7km WSW of Beaumont, CA
#
#             time        updated    tz  \
# 0  1659225367215  1659225585732  None
# 1  1659224909800  1659249070805  None
# 2  1659224154190  1659471266410  None
# 3  1659224149970  1659369063102  None
# 4  1659223381510  1659368607850  None
#
#                                                  url  \
# 0  https://earthquake.usgs.gov/earthquakes/eventp...
# 1  https://earthquake.usgs.gov/earthquakes/eventp...
# 2  https://earthquake.usgs.gov/earthquakes/eventp...
# 3  https://earthquake.usgs.gov/earthquakes/eventp...
# 4  https://earthquake.usgs.gov/earthquakes/eventp...
#
#                                               detail  felt  ...    gap  \
# 0  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  ...    NaN
# 1  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  ...   88.0
# 2  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  ...  311.0
# 3  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  ...   60.0
# 4  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  ...   27.0
#
#    magType        type                                       title  \
# 0       ml  earthquake         M 2.6 - 113 km E of Chignik, Alaska
# 1       md  earthquake  M 1.2 - 11km ENE of Hidden Valley Lake, CA
# 2       ml  earthquake            M 0.2 - 41 km NE of Adak, Alaska
# 3       ml  earthquake       M 1.3 - 11km ESE of Lake Isabella, CA
# 4       ml  earthquake             M 1.4 - 7km WSW of Beaumont, CA
#
#    geometry.type                          geometry.coordinates   Longitude  \
# 0          Point                    [-156.5634, 56.2988, 31.3] -156.563400
# 1          Point              [-122.4426667, 38.8486667, 7.22] -122.442667
# 2          Point  [-176.178833333333, 52.1136666666667, 10.03] -176.178833
# 3          Point                 [-118.3585, 35.5858333, 1.98] -118.358500
# 4          Point             [-117.0481667, 33.9033333, 14.75] -117.048167
#
#     Latitude  Depth                    Time
# 0  56.298800  31.30 2022-07-30 23:56:07.215
# 1  38.848667   7.22 2022-07-30 23:48:29.800
# 2  52.113667  10.03 2022-07-30 23:35:54.190
# 3  35.585833   1.98 2022-07-30 23:35:49.970
# 4  33.903333  14.75 2022-07-30 23:23:01.510
#
# [5 rows x 34 columns]

# %%
df.to_csv('working_time_EQ_July.csv')

# %%
print('Hello')
# Out:
# Hello
